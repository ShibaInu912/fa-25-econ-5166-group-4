# %% [markdown]
# # Data Description
# - Author: Chen-Hung Peng
# - Date first created: 2025-10-14
# - Background: 簡述資料內容
# - Unit of observation: 3993
# - Sample period: 2002-2024
# - Known issues:  None
# - Definition for each variable:
#     - `date`：日期
#     - `year`：年份
#     - `month`：月份
#     - `city_code`：城市代碼
#     - `city`：城市
#     - `station`：氣象測站
#     - `pop_density`：人口密度
#     - `pop_total`：人口總數
#     - `pop_0-14`：0至14歲人口
#     - `pop_15-64`：15至64歲人口
#     - `pop_0-65up`：65歲以上人口
#     - `sunshine_hours`：日照時數
#     - `avg_humidity`：月平均相對濕度
#     - `avg_temp`：月平均氣溫
#     - `rainy_days`：月降水日數
#     - `precipitation`：月降水量
#     - `theft_cases`：竊盜發生件數
#     - `traffic_accident_cases`：駕駛過失發生件數
#     - `alcohol_drive_cases`：酒駕發生件數
#     - `general_injury_cases`：一般傷害發生件數
#     - `total_crime_exclude_traffic`：刑案總件數(不含駕駛過失)
#     - `sexual_assault_cases`：刑案總件數(不含駕駛過失)
#     - `violent_crime_cases`：暴力犯罪發生件數
#     - `drug_cases`：毒品查獲件數

# %%
import pandas as pd

# %% [markdown]
# ## Change for Your Own Data

# %%
input_data_file = "C:/Users/Luca/Desktop/Course/03_Data_Science_and_Social_Inquiry/04_Final_Project/02_data/02_processed/04-weather-crime-pop.csv"

# %%
df = pd.read_csv(input_data_file)

# %% [markdown]
# ### Sample

# %%
df.head(10)
# Out:
#         date  year  month  city_code city station  pop_density  pop_total  \
# 0   2002/1/1  2002      1          1  基隆市      基隆      2948.58     390906
# 1   2002/2/1  2002      2          1  基隆市      基隆      2948.58     390636
# 2   2002/3/1  2002      3          1  基隆市      基隆      2948.58     390732
# 3   2002/4/1  2002      4          1  基隆市      基隆      2948.58     390924
# 4   2002/5/1  2002      5          1  基隆市      基隆      2948.58     390915
# 5   2002/6/1  2002      6          1  基隆市      基隆      2948.58     390764
# 6   2002/7/1  2002      7          1  基隆市      基隆      2948.58     390765
# 7   2002/8/1  2002      8          1  基隆市      基隆      2948.58     390992
# 8   2002/9/1  2002      9          1  基隆市      基隆      2948.58     391047
# 9  2002/10/1  2002     10          1  基隆市      基隆      2948.58     391189
#
#    pop_0-14  pop_15-64  ...  rainy_days  precipitation  theft_cases  \
# 0     78803     276579  ...        13.0          177.1          446
# ...

# %% [markdown]
# ### Summary Stats

# %%
df.describe()
# Out:
#               year       month    city_code  pop_density     pop_total  \
# count  5796.000000  5796.00000  5796.000000  5796.000000  5.796000e+03
# mean   2013.000000     6.50000    11.761905  1556.617992  1.104177e+06
# std       6.633822     3.45235     6.376881  2184.972489  1.077918e+06
# min    2002.000000     1.00000     1.000000    59.800000  8.712000e+03
# 25%    2007.000000     3.75000     7.000000   293.980000  3.274720e+05
# 50%    2013.000000     6.50000    12.000000   845.330000  5.605235e+05
# 75%    2019.000000     9.25000    17.000000  1792.060000  1.875278e+06
# max    2024.000000    12.00000    22.000000  9951.480000  4.047112e+06
#
#             pop_0-14     pop_15-64       pop_65up  sunshine_hours  \
# count    5796.000000  5.796000e+03    5796.000000     4506.000000
# mean   168396.253968  7.974093e+05  138371.346963      153.008389
# std    169448.305894  7.923263e+05  135293.409733       60.246325
# ...

# %% [markdown]
# ### Assertions

# %%
# Write assertions here—conditions that should always hold in the data.
# Use them to demonstrate that you have carefully checked the data’s correctness.
